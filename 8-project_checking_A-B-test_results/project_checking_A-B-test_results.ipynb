# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-и-предобработка-данных" data-toc-modified-id="Загрузка-и-предобработка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка и предобработка данных</a></span></li><li><span><a href="#Приоритизация-гипотез" data-toc-modified-id="Приоритизация-гипотез-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Приоритизация гипотез</a></span></li><li><span><a href="#Анализ-A/B-теста" data-toc-modified-id="Анализ-A/B-теста-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ A/B-теста</a></span><ul class="toc-item"><li><span><a href="#График-кумулятивной-выручки-по-группам." data-toc-modified-id="График-кумулятивной-выручки-по-группам.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>График кумулятивной выручки по группам.</a></span></li><li><span><a href="#График-кумулятивного-среднего-чека-по-группам." data-toc-modified-id="График-кумулятивного-среднего-чека-по-группам.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>График кумулятивного среднего чека по группам.</a></span></li><li><span><a href="#График-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A." data-toc-modified-id="График-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>График относительного изменения кумулятивного среднего чека группы B к группе A.</a></span></li><li><span><a href="#График-кумулятивной-конверсии-по-группам." data-toc-modified-id="График-кумулятивной-конверсии-по-группам.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>График кумулятивной конверсии по группам.</a></span></li><li><span><a href="#График-относительного-изменения-кумулятивной-конверсии-группы-B-к-группе-A." data-toc-modified-id="График-относительного-изменения-кумулятивной-конверсии-группы-B-к-группе-A.-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>График относительного изменения кумулятивной конверсии группы B к группе A.</a></span></li><li><span><a href="#График-количества-заказов-по-пользователям." data-toc-modified-id="График-количества-заказов-по-пользователям.-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>График количества заказов по пользователям.</a></span></li><li><span><a href="#Выбор-границы-для-определения-аномальных-пользователей." data-toc-modified-id="Выбор-границы-для-определения-аномальных-пользователей.-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Выбор границы для определения аномальных пользователей.</a></span></li><li><span><a href="#График-стоимостей-заказов." data-toc-modified-id="График-стоимостей-заказов.-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>График стоимостей заказов.</a></span></li><li><span><a href="#Выбор-границы-для-определения-аномальных-заказов." data-toc-modified-id="Выбор-границы-для-определения-аномальных-заказов.-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Выбор границы для определения аномальных заказов.</a></span></li><li><span><a href="#Статистическая-значимость-различий-в-конверсии-между-группами-по-«сырым»-данным." data-toc-modified-id="Статистическая-значимость-различий-в-конверсии-между-группами-по-«сырым»-данным.-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Статистическая значимость различий в конверсии между группами по «сырым» данным.</a></span></li><li><span><a href="#Статистическая-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным." data-toc-modified-id="Статистическая-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным.-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>Статистическая значимость различий в среднем чеке заказа между группами по «сырым» данным.</a></span></li><li><span><a href="#Статистическая-значимость-различий-в-конверсии-между-группами-по-«очищенным»-данным." data-toc-modified-id="Статистическая-значимость-различий-в-конверсии-между-группами-по-«очищенным»-данным.-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>Статистическая значимость различий в конверсии между группами по «очищенным» данным.</a></span></li><li><span><a href="#Статистическая-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным." data-toc-modified-id="Статистическая-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным.-3.13"><span class="toc-item-num">3.13&nbsp;&nbsp;</span>Статистическая значимость различий в среднем чеке заказа между группами по «очищенным» данным.</a></span></li><li><span><a href="#Решение-по-результатам-теста." data-toc-modified-id="Решение-по-результатам-теста.-3.14"><span class="toc-item-num">3.14&nbsp;&nbsp;</span>Решение по результатам теста.</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Принятие решений в бизнесе на основе данных.

# %% [markdown]
# **Описание проекта**
#
# Вместе с отделом маркетинга интернет-магазина подготовлен список гипотез для увеличения выручки.
# Необходимо приоритизировать гипотезы, запустите A/B-тест и проанализировать результаты.
#
# **Часть 1. Приоритизация гипотез.**
#
# В файле /datasets/hypothesis.csv 9 гипотез по увеличению выручки интернет-магазина с указанными параметрами Reach, Impact, Confidence, Effort.
#
# *Задача*
# - Примените фреймворк ICE для приоритизации гипотез. Отсортируйте их по убыванию приоритета.
# - Примените фреймворк RICE для приоритизации гипотез. Отсортируйте их по убыванию приоритета.
# - Укажите, как изменилась приоритизация гипотез при применении RICE вместо ICE. Объясните, почему так произошло.
#
# **Часть 2. Анализ A/B-теста**
# Проведен A/B-тест и получены результаты, которые описаны в файлах /datasets/orders.csv и /datasets/visitors.csv.
#
# *Задача*
#
# Проанализируйте A/B-тест:
# 1. Постройте график кумулятивной выручки по группам. Сделайте выводы и предположения.
# 2. Постройте график кумулятивного среднего чека по группам. Сделайте выводы и предположения.
# 3. Постройте график относительного изменения кумулятивного среднего чека группы B к группе A. Сделайте выводы и предположения.
# 4. Постройте график кумулятивной конверсии по группам. Сделайте выводы и предположения.
# 5. Постройте график относительного изменения кумулятивной конверсии группы B к группе A. Сделайте выводы и предположения.
# 6. Постройте точечный график количества заказов по пользователям. Сделайте выводы и предположения.
# 7. Посчитайте 95-й и 99-й перцентили количества заказов на пользователя. Выберите границу для определения аномальных пользователей.
# 8. Постройте точечный график стоимостей заказов. Сделайте выводы и предположения.
# 9. Посчитайте 95-й и 99-й перцентили стоимости заказов. Выберите границу для определения аномальных заказов.
# 10. Посчитайте статистическую значимость различий в конверсии между группами по «сырым» данным. Сделайте выводы и предположения.
# 11. Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделайте выводы и предположения.
# 12. Посчитайте статистическую значимость различий в конверсии между группами по «очищенным» данным. Сделайте выводы и предположения.
# 13. Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделайте выводы и предположения.
# 14. Примите решение по результатам теста и объясните его. Варианты решений: 1. Остановить тест, зафиксировать победу одной из групп. 2. Остановить тест, зафиксировать отсутствие различий между группами. 3. Продолжить тест.
#
# **Описание данных**
#
# *Данные для первой части*
# Файл /datasets/hypothesis.csv.
# Hypothesis — краткое описание гипотезы;
# Reach — охват пользователей по 10-балльной шкале;
# Impact — влияние на пользователей по 10-балльной шкале;
# Confidence — уверенность в гипотезе по 10-балльной шкале;
# Efforts — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.
#
# *Данные для второй части*
# Файл /datasets/orders.csv.
# transactionId — идентификатор заказа;
# visitorId — идентификатор пользователя, совершившего заказ;
# date — дата, когда был совершён заказ;
# revenue — выручка заказа;
# group — группа A/B-теста, в которую попал заказ.
# Файл /datasets/visitors.csv.
# date — дата;
# group — группа A/B-теста;
# visitors — количество пользователей в указанную дату в указанной группе A/B-теста

# %% [markdown]
# ## Загрузка и предобработка данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st
import datetime as dt
import warnings

# %%
try:
    hypothesis = pd.read_csv('hypothesis.csv')
    orders = pd.read_csv('orders.csv')
    visitors = pd.read_csv('visitors.csv')
except:
    hypothesis = pd.read_csv('/datasets/hypothesis.csv')
    orders = pd.read_csv('/datasets/orders.csv')
    visitors = pd.read_csv('/datasets/visitors.csv')
    
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Изучим общую информацию о загруженных датасетах.

# %%
for df in [hypothesis, orders, visitors]:
    display(df.head(10))
    print(df.info())
    print('=='*60)
# Out:
#                                                                                                      Hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %% [markdown]
# После первого знакомства с данными можно сделать выводы:
# - пропусков в таблицах не обнаружено;
# - заголовки столбцов в таблице с гипотезами имеют неправильный формат;
# - необходимо изменить формат даты на datetime;
# - нужно проверить таблицы на дубликаты.

# %% [markdown]
# В таблице с гипотезами всего 9 строк, они все отображены в предыдущем выводе, исходя из которого, видно, что все данные корректны. Необходимо только изменить регистр букв в названии столбцов.

# %%
hypothesis.columns = hypothesis.columns.str.lower()

# %% [markdown]
# Изменим тип столбца с датой в таблице с заказами на datetime.

# %%
orders['date'] = orders['date'].map(lambda x: dt.datetime.strptime(x, '%Y-%m-%d'))

# %% [markdown]
# Узнаем за какой период времени хранятся данные в таблице.

# %%
print('Начальная дата {}, конечная дата {}'.format(orders['date'].min(), orders['date'].max()))
# Out:
# Начальная дата 2019-08-01 00:00:00, конечная дата 2019-08-31 00:00:00

# %% [markdown]
# Проверим наличие дубликатов в таблице с заказами.

# %%
print("Количество дубликатов =", orders.duplicated().sum())
# Out:
# Количество дубликатов = 0

# %% [markdown]
# Изменим тип столбца с датой в таблице с посетителями на datetime.

# %%
visitors['date'] = visitors['date'].map(lambda x: dt.datetime.strptime(x, '%Y-%m-%d'))

# %% [markdown]
# Также узнаем за какой период времени хранятся данные в таблице.

# %%
print('Начальная дата {}, конечная дата {}'.format(visitors['date'].min(), visitors['date'].max()))
# Out:
# Начальная дата 2019-08-01 00:00:00, конечная дата 2019-08-31 00:00:00

# %% [markdown]
# Временной период в таблицах с заказами и посетителями совпадает.
#
# Проверим наличие дубликатов.

# %%
print("Количество дубликатов =", visitors.duplicated().sum())
# Out:
# Количество дубликатов = 0

# %% [markdown]
# Проверим нет ли общих пользователей в тестовых группах.

# %%
similarId = list(set(orders.query('group=="A"').visitorId) & set(orders.query('group=="B"').visitorId))
print('Количество общих пользователей в группах =', len(list(set(orders.query('group=="A"').visitorId) & set(orders.query('group=="B"').visitorId))))
# Out:
# Количество общих пользователей в группах = 58

# %%
new_orders = orders[~orders.visitorId.isin(similarId)]

# %% [markdown]
# **ВЫВОД.**
#
# В ходе предобработки данных в таблицах с заказами и посетителями изменены типы столбцов с датой. В таблице с гипотезами установили нижний регистр букв в названии столбцов. Выяснили, что в таблицах хранятся данные за период с 01.08.2019 г. по 31.08.2019 г. Установили, что в тестовых группах имелось 58 общих пользователей, после чего удалили их из таблицы. Данные подготовлены к дальнейшему анализу.

# %% [markdown]
# ## Приоритизация гипотез

# %%
hypothesis
# Out:
#                                                                                                      hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %% [markdown]
# **Приоритезация гипотез методом ICE.**

# %% [markdown]
# Добавим в таблицу с гипотезами два столбца, в которых, в соответствии с установленными формулами, рассчитаем оценки  ICE и RICE.

# %%
hypothesis['ice'] = hypothesis['impact'] * hypothesis['confidence'] / hypothesis['efforts']
hypothesis['rice'] = hypothesis['reach'] * hypothesis['impact'] * hypothesis['confidence'] / hypothesis['efforts']

# %%
display(hypothesis[['hypothesis', 'ice']].sort_values(by='ice', ascending=False))
# Out:
#                                                                                                      hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# **Приоритезация гипотез методом RICE.**

# %%
display(hypothesis[['hypothesis', 'rice']].sort_values(by='rice', ascending=False))
# Out:
#                                                                                                      hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %%
hyp_res = hypothesis[['hypothesis', 'ice', 'rice']].sort_values(by=['ice','rice'], ascending=False).style.background_gradient(cmap='cool')
hyp_res
# Out:
# <style  type="text/css" >
# #T_d8fbb_row0_col1,#T_d8fbb_row2_col2{
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }#T_d8fbb_row0_col2{
#             background-color:  #1fe0ff;
#             color:  #000000;
#         }#T_d8fbb_row1_col1{
#             background-color:  #cf30ff;
#             color:  #f1f1f1;
#         }#T_d8fbb_row1_col2,#T_d8fbb_row3_col2{
#             background-color:  #56a9ff;
#             color:  #000000;
#         }#T_d8fbb_row2_col1{
#             background-color:  #ab54ff;
#             color:  #000000;
#         }#T_d8fbb_row3_col1{
#             background-color:  #758aff;
#             color:  #000000;
#         }#T_d8fbb_row4_col1{
#             background-color:  #659aff;
#             color:  #000000;
#         }#T_d8fbb_row4_col2{
#             background-color:  #7c83ff;
#             color:  #000000;
#         }#T_d8fbb_row5_col1{
#             background-color:  #10efff;
#             color:  #000000;
# ...

# %% [markdown]
# **Вывод.**
#
# По рейтингу ICE наибольшую оценку имели гипотезы 8, 0 и 7. После применения рейтигна RICE приоритеты изменились на гпиотезы 7, 2, 0 и 6 (третье и четвертое место разделили между собой 0 и 6 гипотезы, у обеих по 40 баллов). Это объясняется тем, что в ICE, в отличие от RICE, мы не учитывали охват изменений, тогда как это важная составляющая оценки гипотез. Поэтому наиболее приоритетными гипотезами будут 7, 2, 0 и 6.

# %% [markdown]
# ## Анализ A/B-теста

# %% [markdown]
# Известно, что A/B-тест уже проведен и получены результаты. Но для закрепления пройденного материала проверим, корректно ли был рассчитан размер выборки для проведения теста. Для этого необходимо узнать конверсию из посещения сайта в оформление заказа.

# %%
print('Число посетителей в группе А: {}\n'
      'Число посетителей в группе B: {}'.format(visitors[visitors['group']=='A']['visitors'].sum(), 
                                                 visitors[visitors['group']=='B']['visitors'].sum()))
print('Число заказов в группе A: {}\n'
      'Число заказов в группе B: {}'.format(len(orders[orders['group']=='A']), len(orders[orders['group']=='B'])))


conversionA = len(orders[orders['group']=='A']) / visitors[visitors['group']=='A']['visitors'].sum() 
conversionB = len(orders[orders['group']=='B']) / visitors[visitors['group']=='B']['visitors'].sum()
print('Конверсия до изменений: {:.3f}'.format(conversionA))
print('Конверсия после изменений: {:.3f}'.format(conversionB))
print('Относительное изменение конверсии после изменений: {:.3f}'.format(abs(1-(conversionA/conversionB))))
# Out:
# Число посетителей в группе А: 18736
# Число посетителей в группе B: 18916
# Число заказов в группе A: 557
# Число заказов в группе B: 640
# Конверсия до изменений: 0.030
# Конверсия после изменений: 0.034
# Относительное изменение конверсии после изменений: 0.121

# %% [markdown]
# Полученные значения конверсии введем в калькулятор для расчета размера выборки, расположенный на сайте https://www.evanmiller.org/ab-testing/sample-size.html.
# По расчету калькулятора необходимый размер выборки равен 35269. В нашем проекте размер выборки (общее число посетителей) составляет 37652. Это значит, что размер выборки для проведения A/B-теста был верно подобран.

# %% [markdown]
# ### График кумулятивной выручки по группам.

# %% [markdown]
# В начале создадим таблицу кумулятивных данных.

# %%
#достаем уникальные значения дат и групп
datesGroups = orders[['date','group']].drop_duplicates().sort_values(by=['date', 'group'])
#выводим кумулятивные показатели из orders
ordersAggregated = datesGroups.apply(lambda x: orders[np.logical_and(x['date'] >= orders['date'], x['group']==orders['group'])]\
.agg({'date':'max', 'group':'max', 'transactionId':'nunique', 'visitorId':'nunique', 'revenue':'sum'}), axis = 1)
ordersAggregated.columns = ['date', 'group', 'orders', 'buyers', 'revenue']
#выводим кумулятивные показатели из visitors
visitorsAggregated = datesGroups.apply(lambda x: visitors[np.logical_and(x['date'] >= visitors['date'], x['group']==visitors['group'])]\
.agg({'date':'max', 'group':'max', 'visitors':'sum'}), axis = 1)
#сводим все накопительные данные в одну таблицу
cummulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cummulativeData.head(5)
# Out:
#         date group  orders  buyers  revenue  visitors
# 0 2019-08-01     A      24      20   148579       719
# 1 2019-08-01     B      21      20   101217       713
# 2 2019-08-02     A      44      38   242401      1338
# 3 2019-08-02     B      45      43   266748      1294
# 4 2019-08-03     A      68      62   354874      1845

# %% [markdown]
# По полученным данным построим график кумулятивной выручки по группам.

# %%
cummulativeDataA = cummulativeData[cummulativeData['group']=='A']
cummulativeDataB = cummulativeData[cummulativeData['group']=='B']

plt.figure(figsize=(18,6))
plt.grid()
plt.plot(cummulativeDataA['date'], cummulativeDataA['revenue'], label = 'A')
plt.plot(cummulativeDataB['date'], cummulativeDataB['revenue'], label = 'B')
plt.ylabel('Выручка')
plt.xlabel('Дата')
plt.title('Графики кумулятивной выручки по группам A/B')
plt.annotate('расхождение', xy=(dt.date(2019, 8, 5), 650000), xytext=(dt.date(2019, 8, 2), 1000000), arrowprops=dict(facecolor='g'))
plt.annotate('скачок', xy=(dt.date(2019, 8, 19), 4150000), xytext=(dt.date(2019, 8, 17), 5000000), arrowprops=dict(facecolor='g'))
plt.axis([dt.date(2019, 8, 1), dt.date(2019, 8, 31), 0, 6000000])
plt.legend()
plt.show()

# %% [markdown]
# Первые 5 дней выручки обеих групп были практически одинаковы. Начиная с 6 августа выручка группы "B" росла с незначительным преимуществом над группой "A". Отмечен резкий всплеск выручки в группе "B" 19 августа, скорее всего, это был крупный заказ. После этого дня графики шли практически параллельными курсами.
# Проверим, какие заказы были 19 августа.

# %%
display(orders.query('date == "2019-08-19"').sort_values(by='revenue', ascending=False).head())
print('Медианная выручка за 19 августа =',orders.query('date == "2019-08-19"')['revenue'].median())
# Out:
#      transactionId   visitorId       date  revenue group
# 425      590470918  1920142716 2019-08-19  1294500     B
# 530     3970235543  2912540959 2019-08-19    43990     A
# 527     1570513684  2837914161 2019-08-19    33405     B
# 421     3765974140  1357170471 2019-08-19    31680     A
# 461     2683113224   154576532 2019-08-19    26550     B
# Медианная выручка за 19 августа = 2630.0

# %% [markdown]
# Как видно посетитель с ID 1920142716 совершил крупный заказ (1294500 руб.), который значительно превышает медианное значение выручки в этот день. Будем учитывать эту информацию в дальнейшем анализе.

# %% [markdown]
# ### График кумулятивного среднего чека по группам.

# %% [markdown]
# Для построения графика среднего кумулятивного чека по группам необходимо разделить кумулятивную выручку на кумулятивное число заказов.

# %%
plt.figure(figsize=(18,6))
plt.grid()
plt.plot(cummulativeDataA['date'], cummulativeDataA['revenue']/cummulativeDataA['orders'], label = 'A')
plt.plot(cummulativeDataB['date'], cummulativeDataB['revenue']/cummulativeDataB['orders'], label = 'B')
plt.title('Графики кумулятивного среднего чека по группам A/B')
plt.ylabel('Средний чек')
plt.xlabel('Дата')
plt.annotate('скачок', xy=(dt.date(2019, 8, 19), 10200), xytext=(dt.date(2019, 8, 16), 9000), arrowprops=dict(facecolor='g'))
plt.axis([dt.date(2019, 8, 1), dt.date(2019, 8, 31), 4000, 11000])
plt.legend()
plt.show()

# %% [markdown]
# Анализируя график, видно, что первую половину месяца в обеих группах уровень среднего чека имел заметные колебания. За период до 15 августа средний чек в группе "B" преимущественно больше, чем в группе "A". В группе "А" чек больше только 1, 12-14 августа. 15 августа графики пересекаются, и после этого средний чек группы "А" уже имел устоявшийся график с небольшим приростом. На график "B" также, как и в случае с кумулятивной выручкой, оказал влияние аномальный заказ от 19 августа (видим всплеск на графике).После 19 августа средний чек в группе "B" немного снизился и достиг стабильного уровня примерно 9200 рублей.

# %% [markdown]
# ### График относительного изменения кумулятивного среднего чека группы B к группе A.

# %% [markdown]
# Объединим данные в одном датафрейме и построим график относительного изменения кумулятивного среднего чека.

# %%
mergedCummulativeData = cummulativeDataA.merge(cummulativeDataB, left_on='date', right_on='date', suffixes=['A', 'B'])

plt.figure(figsize=(18,6))
plt.grid()
plt.plot(mergedCummulativeData['date'], ((mergedCummulativeData['revenueB']/mergedCummulativeData['ordersB'])/
                                       (mergedCummulativeData['revenueA']/mergedCummulativeData['ordersA'])-1))
plt.axhline(y=0, color='black', linestyle = '--')
plt.title('График относительного изменения кумулятивного среднего чека группы B к группе A')
plt.xlabel('Дата')
plt.show()

# %% [markdown]
# В нескольких точках график различия между сегментами резко «скачет», что говорит об аномалиях и выбросах в данных. Один из выбросов мы уже знаем - крупный заказ от 19 августа. Необходимо будет проверить данные на наличие других аномалий.

# %% [markdown]
# ### График кумулятивной конверсии по группам.

# %% [markdown]
# Добавим в объединенный датафрейм значения конверсии и построим по этим данным график.

# %%
mergedCummulativeData['conversionA'] =  mergedCummulativeData['ordersA'] / mergedCummulativeData['visitorsA'] 
mergedCummulativeData['conversionB'] =  mergedCummulativeData['ordersB'] / mergedCummulativeData['visitorsB']

plt.figure(figsize=(18,6))
plt.grid()
plt.plot(mergedCummulativeData['date'], mergedCummulativeData['conversionA'], label='A')
plt.plot(mergedCummulativeData['date'], mergedCummulativeData['conversionB'], label='B')
plt.title('График кумулятивной конверсии по группам A/B')
plt.xlabel('Дата')
plt.ylabel('Конверсия')
plt.annotate('отрыв группы B', xy=(dt.date(2019, 8, 6), 0.0327), xytext=(dt.date(2019, 8, 6), 0.0355), arrowprops=dict(facecolor='g'))
plt.axis([dt.date(2019, 8, 1), dt.date(2019, 8, 31), 0.029, 0.037])
plt.legend()
plt.show()

# %% [markdown]
#  С 1 по 10 августа на графике видны значительные колебания. До 6 августа конверсия группы "А" превышала конверсию группы "B". После  6 августа конверсия группы "B" вышла вперед, и уже до конца рассматриваемого периода стабильно показывала большую конверсию чем группа "A".

# %% [markdown]
# ###  График относительного изменения кумулятивной конверсии группы B к группе A.

# %%
plt.figure(figsize=(18,6))
plt.grid()
plt.plot(mergedCummulativeData['date'], ((mergedCummulativeData['conversionB']/mergedCummulativeData['conversionA'])-1))
plt.title('График относительного изменения кумулятивной конверсии группы B к группе A')
plt.axhline(y=0, color='black', linestyle='--')
plt.axhline(y=0.1, color='grey', linestyle='--')
plt.axhline(y=0.2, color='grey', linestyle='--') 
plt.xlabel('Дата')
plt.show()

# %% [markdown]
# На графике видно, что, как и в предыдущем пункте, конверсия группы "B" до 6 августа уступала конверсии группы "А", за исключением одного дня - 2 августа, возможно, в тот день хорошо сработала рекламная компания. Начиная с 6 августа группа "B" лидировала до конца периода. Её конверсия росла до 15 августа и разница с группой "A" на максимуме составила 21%, затем пошло постепенное снижение отностельной конверсии до 12%-14%.

# %% [markdown]
# ### График количества заказов по пользователям.

# %% [markdown]
# Подсчитаем количество заказов по пользователям и посмотрим на результат.

# %%
ordersByUsers = orders.groupby('visitorId', as_index = False).agg({'transactionId':'nunique'}).sort_values(by='transactionId', ascending = False)
ordersByUsers.columns = ['visitorId', 'orders']
display(ordersByUsers.head(5))
print('среднее число заказов равно', round(ordersByUsers.orders.mean(), 1))
# Out:
#        visitorId  orders
# 1023  4256040402      11
# 591   2458001652      11
# 569   2378935119       9
# 487   2038680547       8
# 44     199603092       5
# среднее число заказов равно 1.2

# %% [markdown]
# Есть пользователи, которые совершали 5, 8, 9 и 11 заказов. Значительно больше, чем в среднем за тот же период.
#
# Построим точечную диаграмму числа заказов на одного пользователя.

# %%
x_values = pd.Series(range(0, len(ordersByUsers)))
plt.figure(figsize=(18,6))
plt.grid()
plt.scatter(x_values, ordersByUsers['orders'], alpha=0.3)
plt.title('График количества заказов по пользователям')
plt.show()

# %% [markdown]
# График подтверждает, что подавляющее большинство пользователей совершило 1 заказ. Есть небольшое количество пользователей, совершивших 2-3 заказа, но их точная доля не ясна — пока непонятно, считать их аномалиями или нет, нужно посчитать перцентили.

# %% [markdown]
# ### Выбор границы для определения аномальных пользователей.

# %% [markdown]
# Посчитаем 95-й и 99-й перцентили количества заказов на пользователя.

# %%
percentiles = np.percentile(ordersByUsers['orders'], [95, 99])
print(f'95-й перцентиль = {percentiles[0]}, 99-й перцентиль = {percentiles[1]}')
# Out:
# 95-й перцентиль = 2.0, 99-й перцентиль = 4.0

# %% [markdown]
# Из расчета видно, что как минимум 95 % пользователей совершают не более 2 заказов. Всё, что выше этого значения примем за аномалию.

# %% [markdown]
# ### График стоимостей заказов.

# %% [markdown]
# Чтобы заказ стоимостью почти 1,3 миллиона рублей не помешал более детально изучить график, ограничимся значениями по оси y до 150 тысяч рублей.

# %%
x_values = pd.Series(range(0, len(orders)))
plt.figure(figsize=(18,6))
plt.grid()
plt.scatter(x_values, orders['revenue'], alpha=0.5)
plt.title('График стоимостей заказов')
plt.axis([0, 1200, 0, 150000])
plt.show()

# %% [markdown]
# Основная доля заказов укладывалась в стоимость около 5 - 10 тысяч рублей. Чтобы найти более точную обработку стоимости аномальных заказов, найдем их перцентили.

# %% [markdown]
# ### Выбор границы для определения аномальных заказов.

# %% [markdown]
# Посчитаем 95-й и 99-й перцентили стоимости заказов.

# %%
percentiles = np.percentile(orders['revenue'], [95, 99])
print(f'95-й перцентиль = {round(percentiles[0], 2)}, 99-й перцентиль = {round(percentiles[1], 2)}')
# Out:
# 95-й перцентиль = 28000.0, 99-й перцентиль = 58233.2

# %% [markdown]
# Из расчета видно, что 99 % пользователей совершают заказы на сумму до 58233 рублей. Всё, что выше этого значения примем за аномалию.

# %% [markdown]
# ### Статистическая значимость различий в конверсии между группами по «сырым» данным.

# %% [markdown]
# Прежде чем определить статистичискую значимость необходимо подготовить данные. Соберем все данные по заказам, визитам и кумулятивным показателям в соответствующие таблицы.

# %%
visitorsADaily = visitors[visitors['group']=='A'][['date', 'visitors']]
visitorsADaily.columns = ['date', 'visitorsPerDateA']

visitorsACummulative = visitorsADaily.apply(lambda x: visitorsADaily[visitorsADaily['date'] <= x['date']]. \
                                            agg({'date' : 'max', 'visitorsPerDateA' : 'sum'}), axis=1)
visitorsACummulative.columns = ['date', 'visitorsCummulativeA']

visitorsBDaily = visitors[visitors['group']=='B'][['date', 'visitors']]
visitorsBDaily.columns = ['date', 'visitorsPerDateB']

visitorsBCummulative = visitorsBDaily.apply(lambda x: visitorsBDaily[visitorsBDaily['date'] <= x['date']]. \
                                            agg({'date' : 'max', 'visitorsPerDateB' : 'sum'}), axis=1)
visitorsBCummulative.columns = ['date', 'visitorsCummulativeB']


ordersADaily = orders[orders['group']=='A'][['date', 'transactionId', 'visitorId', 'revenue']]\
    .groupby('date', as_index=False)\
    .agg({'transactionId' : pd.Series.nunique, 'revenue' : 'sum'})
ordersADaily.columns = ['date', 'ordersPerDateA', 'revenuePerDateA']

ordersACummulative = ordersADaily.apply(
    lambda x: \
        ordersADaily[ordersADaily['date'] <= x['date']]\
            .agg({
                'date' : 'max',
                'ordersPerDateA' : 'sum',
                'revenuePerDateA' : 'sum'}), axis=1).sort_values(by=['date'])
ordersACummulative.columns = ['date', 'ordersCummulativeA', 'revenueCummulativeA']

ordersBDaily = orders[orders['group']=='B'][['date', 'transactionId', 'visitorId', 'revenue']]\
    .groupby('date', as_index=False)\
    .agg({'transactionId' : pd.Series.nunique, 'revenue' : 'sum'})
ordersBDaily.columns = ['date', 'ordersPerDateB', 'revenuePerDateB']

ordersBCummulative = ordersBDaily.apply(
    lambda x: \
        ordersBDaily[ordersBDaily['date'] <= x['date']]\
            .agg({
                'date' : 'max',
                'ordersPerDateB' : 'sum',
                'revenuePerDateB' : 'sum'}), axis=1).sort_values(by=['date'])
ordersBCummulative.columns = ['date', 'ordersCummulativeB', 'revenueCummulativeB']

# %% [markdown]
# И затем объеденим полученные данные в одну таблицу.

# %%
data = ordersADaily.merge(ordersBDaily, left_on='date', right_on='date', how='left')\
    .merge(ordersACummulative, left_on='date', right_on='date', how='left')\
    .merge(ordersBCummulative, left_on='date', right_on='date', how='left')\
    .merge(visitorsADaily, left_on='date', right_on='date', how='left')\
    .merge(visitorsBDaily, left_on='date', right_on='date', how='left')\
    .merge(visitorsACummulative, left_on='date', right_on='date', how='left')\
    .merge(visitorsBCummulative, left_on='date', right_on='date', how='left')
data.head(5)
# Out:
#         date  ordersPerDateA  revenuePerDateA  ordersPerDateB  \
# 0 2019-08-01              24           148579              21
# 1 2019-08-02              20            93822              24
# 2 2019-08-03              24           112473              16
# 3 2019-08-04              16            70825              17
# 4 2019-08-05              25           124218              23
#
#    revenuePerDateB  ordersCummulativeA  revenueCummulativeA  \
# 0           101217                  24               148579
# 1           165531                  44               242401
# 2           114248                  68               354874
# 3           108571                  84               425699
# 4            92428                 109               549917
#
#    ordersCummulativeB  revenueCummulativeB  visitorsPerDateA  \
# 0                  21               101217               719
# 1                  45               266748               619
# ...

# %% [markdown]
# Применим критерий и отформатируем p-value, округлив его до трёх знаков после запятой.
# В переменную `sampleA` сохраним выборку, где каждый элемент — число заказов определённого пользователя, в том числе ноль. Число элементов `sampleA` — это количество пользователей, сумма всех элементов — количество заказов. Чтобы получить конверсию в группе, поделим сумму заказов на число пользователей — найдём среднее в выборке `sampleA` методом `mean()`. Аналогично найдём конверсию группы B.
#
# Выведем относительный прирост конверсии группы B рассчитываемый по формуле: `конверсия группы B / конверсия группы A - 1`. Округлим до трёх знаков после запятой. Пороговое значение возьмём равное 5%.
#
# Сформулируем гипотезы. Нулевая: различий в конверсии между группами нет. Альтернативная: различия в конверсии между группами есть.

# %%
ordersByUsersA = orders[orders['group']=='A'].groupby('visitorId', as_index=False).agg({'transactionId' : pd.Series.nunique})
ordersByUsersA.columns = ['userId', 'orders']

ordersByUsersB = orders[orders['group']=='B'].groupby('visitorId', as_index=False).agg({'transactionId' : pd.Series.nunique})
ordersByUsersB.columns = ['userId', 'orders']

sampleA = pd.concat([ordersByUsersA['orders'],pd.Series(0, index=np.arange(data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])), name='orders')],axis=0)

sampleB = pd.concat([ordersByUsersB['orders'],pd.Series(0, index=np.arange(data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])), name='orders')],axis=0)

print("p-value = {0:.3f}".format(st.mannwhitneyu(sampleA, sampleB, alternative = 'two-sided')[1]))
print("Относительный прирост конверсии группы B по отношению к группе A = {0:.3f}".format(sampleB.mean()/sampleA.mean()-1))
# Out:
# p-value = 0.017
# Относительный прирост конверсии группы B по отношению к группе A = 0.138

# %% [markdown]
# **Значение p-value получили равным 0.017, что меньше 0.05. Значит, нулевую гипотезу о том, что статистически значимых различий в конверсии между группами нет - отвергаем. Из этого делаем вывод, что по «сырым» данным различия в конверсии групп "A" и "B" есть. Относительный прирост конверсии группы "B" по отношению к группе "A" равен 13.8%.**

# %% [markdown]
# ### Статистическая значимость различий в среднем чеке заказа между группами по «сырым» данным.

# %% [markdown]
# Чтобы рассчитать статистическую значимость различий в среднем чеке между группами, передадим критерию `mannwhitneyu()` данные о выручке с заказов. Пороговое значение возьмём равное 5%. Также найдём относительные различия в среднем чеке между группами.
#
# Нулевую гипотезу сформулируем как: "статистически значимых различий в средних чеках между группами нет"; тогда альтернативная гипотеза будет: "статистически значимые различия в средних чеках между группами есть".

# %%
print("p-value = {0:.3f}".format(
    st.mannwhitneyu(orders[orders['group']=='A']['revenue'], 
                    orders[orders['group']=='B']['revenue'], alternative = 'two-sided')[1]))
print("Относительное изменение среднего чека в группе B по отношению группы A = {0:.3f}"
      .format(orders[orders['group']=='B']['revenue']
              .mean()/orders[orders['group']=='A']['revenue'].mean()-1))
# Out:
# p-value = 0.729
# Относительное изменение среднего чека в группе B по отношению группы A = 0.259

# %% [markdown]
# **Значение p-value значительно больше 0.05. Следовательно, нулевую гипотезу не отвергаем, а это значит, что в среднем чеке статистически значимых различий в средних чеках между группами нет. То есть средние чеки по "сырым" данным схожи. Но при этом, средний чек группы "B" существенно выше среднего чека группы "A" - почти на 26%.**

# %% [markdown]
# ### Статистическая значимость различий в конверсии между группами по «очищенным» данным.

# %% [markdown]
# Ранее, при определении границ аномалий в предыдущих пунктах, мы приняли за аномальных пользователей тех, кто совершил больше 2 заказов или совершил заказ дороже 28000 рублей. Сделаем срезы пользователей с числом заказов больше 2 — `usersWithManyOrders` и пользователей, совершивших заказы дороже 28000 рублей — `usersWithExpensiveOrders`. Объединим их в таблице `abnormalUsers` и узнаем, сколько всего аномальных пользователей.

# %%
order_limit = 2
revenue_limit = 58233
usersWithManyOrders = pd.concat([ordersByUsersA[ordersByUsersA['orders'] > order_limit]['userId'], 
                                 ordersByUsersB[ordersByUsersB['orders'] > order_limit]['userId']], axis = 0)
usersWithExpensiveOrders = orders[orders['revenue'] > revenue_limit]['visitorId']
abnormalUsers = pd.concat([usersWithManyOrders, usersWithExpensiveOrders], axis = 0).drop_duplicates().sort_values()
display(abnormalUsers.head(5))
print("Всего аномальных пользователей =", len(abnormalUsers))
# Out:
# 1099    148427295
# 18      199603092
# 23      237748145
# 37      249864742
# 68      457167155
# dtype: int64
# Всего аномальных пользователей = 31

# %% [markdown]
# Теперь узнаем, как их действия повлияли на результаты теста. Посчитаем статистическую значимость различий в конверсии между группами теста по очищенным данным. Сначала подготовим выборки количества заказов по пользователям по группам теста.

# %%
sampleAFiltered = pd.concat([ordersByUsersA[np.logical_not(ordersByUsersA['userId'].isin(abnormalUsers))]['orders'], \
                             pd.Series(0, index=np.arange(data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])), \
                                       name='orders')],axis=0)

sampleBFiltered = pd.concat([ordersByUsersB[np.logical_not(ordersByUsersB['userId'].isin(abnormalUsers))]['orders'], \
                             pd.Series(0, index=np.arange(data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])), \
                                       name='orders')],axis=0)

# %% [markdown]
# Применим статистический критерий Манна-Уитни к полученным выборкам.
# Опять же сформулируем гипотезы. Нулевая: различий в конверсии между группами нет. Альтернативная: различия в конверсии между группами есть.

# %%
print("p-value = {0:.3f}".format(st.mannwhitneyu(sampleAFiltered, sampleBFiltered, alternative = 'two-sided')[1]))
print("Относительный прирост конверсии группы B по отношению к группе A по 'очищенным' данным = {0:.3f}"
      .format(sampleBFiltered.mean()/sampleAFiltered.mean()-1))
# Out:
# p-value = 0.010
# Относительный прирост конверсии группы B по отношению к группе A по 'очищенным' данным = 0.174

# %% [markdown]
# **Значение p-value равное 0.010 меньше порогового значения  равного 0.05. Следовательно, нулевую гипотезу отвергаем. Это значит, что и по «отфильтрованным» данным различия в конверсии групп "A" и "B" есть. Относительный прирост конверсии группы "B" по отношению к группе "A" по "очищенным" данных равен 17.4%, что больше, чем с «сырыми» данными (13.8%).**

# %% [markdown]
# ### Статистическая значимость различий в среднем чеке заказа между группами по «очищенным» данным.

# %% [markdown]
# Теперь узнаем, произошло ли что-нибудь с результатами по среднему чеку после фильтрации данных.
#
# Нулевую гипотезу сформулируем как: "статистически значимых различий в средних чеках между группами нет"; тогда альтернативная гипотеза будет: "статистически значимые различия в средних чеках между группами есть".

# %%
print("p-value = {0:.3f}".format(st.mannwhitneyu(
    orders[np.logical_and(
        orders['group']=='A',
        np.logical_not(orders['visitorId'].isin(abnormalUsers)))]['revenue'],
    orders[np.logical_and(
        orders['group']=='B',
        np.logical_not(orders['visitorId'].isin(abnormalUsers)))]['revenue'], alternative = 'two-sided')[1]))

print("Относительное изменение среднего чека в группе B по отношению группы A после очистки данных = {0:.3f}".format(
    orders[np.logical_and(orders['group']=='B',np.logical_not(orders['visitorId'].isin(abnormalUsers)))]['revenue'].mean()/
    orders[np.logical_and(
        orders['group']=='A',
        np.logical_not(orders['visitorId'].isin(abnormalUsers)))]['revenue'].mean() - 1))
# Out:
# p-value = 0.798
# Относительное изменение среднего чека в группе B по отношению группы A после очистки данных = -0.020

# %% [markdown]
# **Значение p-value значительно больше 0.05. Следовательно, нулевую гипотезу не отвергаем, а это значит, что в среднем чеке статистически значимых различий в средних чеках между группами нет, как и в ситуации с "сырыми" данными. Средний чек группы "B" оказался немного ниже среднего чека группы "A" (на 2%), в то время как по "сырым" данным, он был больше почти на 26%. Получается вляние одного аномального заказа на 1,3 млн оказалось существенным.**

# %% [markdown]
# ### Решение по результатам теста.

# %% [markdown]
# Подведем итоги исследования результатов решения A/B-теста. Перед анализом результатов теста проверили, что выборка данных имеет корректный размер, поэтому проблему подглядывания в результате сравнения групп во время проведения теста мы исключили. Кумулятивные метрики по выручке, среднему чеку и конверсии почти все время лидировали в группе "B". Были некоторые сомнения из-за резких колебаний на графике кумулятивного среднего чека в группе "B" до очистки данных от аномальных пользователей. Сомнения подтвердились, т.к. после фильтрации данных разница между средними чеками стала минимальна, но это не дало повода усомниться в проведении теста и его результатах. До и после очистки данных, показатель конверсии в группе "B" больше показателя в группе "A" - на 13.8% до очистки  и на 17.3% после очистки данных. Данная разница показателей конверсии между группами как до, так и после очистки данных является *статистически значимой*, что позволяет нам сделать вывод о том, что **мы можем остановить A/B-тест и зафиксировать победу группы "B"**.
